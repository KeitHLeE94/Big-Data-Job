# %%
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)

# %%
total = client.get_database('total_db')

# %%
diaper = total.get_collection('Diaper')

# %%
diaperResult = diaper.find({})

# %%
diaperList = list(diaperResult)

# %%
len(diaperList)
# Out:
# 622

# %%
for i in range(len(diaperList)):
    if type(diaperList[i]['price']) == str:
        diaperList[i]['price'] = int(diaperList[i]['price'].replace(',', '').replace('\n', '').replace('원', '').replace('~', ''))

# %%
count = 0

for item in diaperList:
    print(type(item['price']))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
for item in diaperList:
    if type(item['replyCount']) == str:
        print(item['replyCount'])

# %%
for item in diaperList:
    if item['replyCount'] == 'No reply':
        item['replyCount'] = 0

# %%
for item in diaperList:
    if type(item['replyCount']) == str:
        item['replyCount'] = int(item['replyCount'].replace('개의 후기', '').replace(',', ''))

# %%
for item in diaperList:
    if item['rating'] == None:
        item['rating'] = 0

# %%
for item in diaperList:
    if item['rating'] == 'No rating':
        item['rating'] = 0

# %%
for item in diaperList:
    item['rating'] = float(item['rating'])

# %%
for item in diaperList:
    print(item['rating'])
# Out:
# 5.0
# 4.5
# 5.0
# 4.5
# 4.5
# 5.0
# 5.0
# 4.5
# 4.5
# 5.0
# 4.5
# 4.5
# 4.5
# 5.0
# 5.0
# 4.5
# 4.5
# 4.5
# 4.5
# 5.0
# 4.5
# 5.0
# 4.5
# 4.5
# 4.5
# 5.0
# 5.0
# 5.0
# 4.5
# 4.5
# 5.0
# 4.5
# 4.5
# 5.0
# 5.0
# 4.5
# 5.0
# 5.0
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 5.0
# 4.5
# 5.0
# 4.5
# 5.0
# 4.5
# 5.0
# 4.5
# 4.5
# 4.5
# 5.0
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 5.0
# 4.5
# 4.5
# 5.0
# 4.5
# 3.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 5.0
# 5.0
# 4.5
# 5.0
# 4.5
# 4.5
# 5.0
# 4.5
# 5.0
# 5.0
# 5.0
# 4.5
# 4.5
# 4.5
# 5.0
# 4.5
# 4.5
# 5.0
# 5.0
# 4.5
# 4.5
# 4.5
# 5.0
# 4.5
# 5.0
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.0
# 4.5
# 4.5
# 4.5
# 4.5
# 4.0
# 4.5
# 5.0
# 4.0
# 4.5
# 4.0
# 5.0
# 4.5
# 3.0
# 4.0
# 5.0
# 4.5
# 4.0
# 5.0
# 4.5
# 4.0
# 4.5
# 3.5
# 4.0
# 5.0
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.0
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.0
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.0
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.5
# 4.0
# 4.5
# 4.0
# 4.5
# ...

# %%
for item in diaperList:
    print(type(item['replyCount']))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
diaper_collection = total.get_collection('Diaper')

# %%
diaper_collection.insert_many([
    diaperList[i] for i in range(len(diaperList))
])

# %% [markdown]
# ___

# %%
milkpowder = total.get_collection('Milkpowder')

milkpowderResult = milkpowder.find({})
milkpowderList = list(milkpowderResult)

len(milkpowderList)
# Out:
# 392

# %%
for item in milkpowderList:
    if type(item['price']) == str:
        item['price'] = int(item['price'].replace(',', '').replace('\n', '').replace('원', '').replace('~', ''))

# %%
for item in milkpowderList:
    if item['replyCount'] == 'No reply':
        item['replyCount'] = 0

# %%
for item in milkpowderList:
    if type(item['replyCount']) == str:
        item['replyCount'] = int(item['replyCount'].replace('개의 후기', '').replace(',', ''))

# %%
for item in milkpowderList:
    print(type(item['replyCount']))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
for item in milkpowderList:
    if item['rating'] == None:
        item['rating'] = 0

# %%
for item in milkpowderList:
    if item['rating'] == 'No rating':
        item['rating'] = 0

# %%
for item in milkpowderList:
    if item['rating'] == 'rating 몰라':
        item['rating'] = 0

# %%
for item in milkpowderList:
    item['rating'] = float(item['rating'])

# %%
for item in milkpowderList:
    print(type(item['rating']))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# ...

# %%
milkpowder_collection = total.get_collection('Milkpowder')

milkpowder_collection.insert_many([
    milkpowderList[i] for i in range(len(milkpowderList))
])

# %% [markdown]
# ___

# %%
snack = total.get_collection('Snack')

snackResult = snack.find({})
snackList = list(snackResult)

len(snackList)
# Out:
# 385

# %%
for item in snackList:
    if type(item['price']) == str:
        item['price'] = int(item['price'].replace(',', '').replace('\n', '').replace('원', '').replace('~', ''))

# %%
for item in snackList:
    print(type(item['price']))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
for item in snackList:
    if item['replyCount'] == 'No reply':
        item['replyCount'] = 0

# %%
for item in snackList:
    if type(item['replyCount']) == str:
        item['replyCount'] = int(item['replyCount'].replace('개의 후기', '').replace(',', ''))

# %%
for item in snackList:
    print(type(item['replyCount']))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
for item in snackList:
    if item['rating'] == None:
        item['rating'] = 0

# %%
for item in snackList:
    if item['rating'] == 'No rating':
        item['rating'] = 0

# %%
for item in snackList:
    if item['rating'] == 'rating 몰라':
        item['rating'] = 0

# %%
for item in snackList:
    item['rating'] = float(item['rating'])

# %%
for item in snackList:
    print(type(item['rating']))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# ...

# %%
snack_collection = total.get_collection('Snack')

snack_collection.insert_many([
    snackList[i] for i in range(len(snackList))
])

# %% [markdown]
# ___

# %%
toy = total.get_collection('Toy')

toyResult = toy.find({})
toyList = list(toyResult)

len(toyList)
# Out:
# 2239

# %%
for item in toyList:
    if type(item['price']) == str:
        item['price'] = int(item['price'].replace(',', '').replace('\n', '').replace('원', '').replace('~', ''))

# %%
for item in toyList:
    print(type(item['price']))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
for item in toyList:
    if item['replyCount'] == 'No reply':
        item['replyCount'] = 0

# %%
for item in toyList:
    if type(item['replyCount']) == str:
        item['replyCount'] = int(item['replyCount'].replace('개의 후기', '').replace(',', ''))

# %%
for item in toyList:
    print(type(item['replyCount']))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
for item in toyList:
    if item['rating'] == None:
        item['rating'] = 0

# %%
for item in toyList:
    if item['rating'] == 'No rating':
        item['rating'] = 0

# %%
for item in toyList:
    if item['rating'] == 'rating 몰라':
        item['rating'] = 0

# %%
for item in toyList:
    item['rating'] = float(item['rating'])

# %%
for item in toyList:
    print(type(item['rating']))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# ...

# %%
toy_collection = total.get_collection('Toy')

toy_collection.insert_many([
    toyList[i] for i in range(len(toyList))
])
